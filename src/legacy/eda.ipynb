# %% [markdown]
# ## To-Dos
#
# ### Basic
#
# - [x] Filter out players that should not acount for statistics
# - [x] Calculate averages with top 10 per position
# - [x] Calculate averages with top 50 general
# - [x] Include new players for this season
# - [x] Include players that got injured early last season
# - [x] Add position value (position average against general average)
# - [x] Assign tiers manually in final board
#
# ### Intermediate
#
# - [ ] Include missing players from app
# - [ ] Identify unavailable players from last season who will return well (steals) (Cartola blogs)
# - [x] Recalculate z-score using per-position number of players (GK: 10, CB: 20, FB: 20, MD: 30, AT: 30)
# - [x] Add risk factor (with gamma to penalize unavailability less because z_all does it already)
#
# ### Advanced
#
# - [x] Add floor factor (see ChatGPT)
# - [x] Add Average Draft Position (ADP)
#
# ### Analysis
#
# - [x] Prepare board for usage in 2026 season (quick filters, quick evaluation)
# - [x] Rescore position tier
# - [x] Score general tier
# - [x] Reassign position and general ADP based on tiers
# - [x] Send to WhatsApp

# %%
! source venv/bin/activate
! pip install pandas
! pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://aws:****@dsi-835811189142.d.codeartifact.eu-west-1.amazonaws.com/pypi/dsi_repository/simple
# Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.11/site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://aws:****@dsi-835811189142.d.codeartifact.eu-west-1.amazonaws.com/pypi/dsi_repository/simple
# Requirement already satisfied: openpyxl in ./venv/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in ./venv/lib/python3.11/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
def prepare_data(year: int, num_round: int) -> pd.DataFrame:
    
    data_round = pd.read_csv(f"data/01_raw/{year}/rodada-{num_round}.csv")
    
    cols = {
        "atletas.atleta_id": "id",
        "atletas.apelido": "name",
        "atletas.clube.id.full.name": "team",
        "atletas.posicao_id": "position_id",
        "atletas.jogos_num": "matches",
        "atletas.pontos_num": "pts_round",
        "atletas.media_num": "pts_avg_played",
        "atletas.entrou_em_campo": "has_played",
    }
    data_round = data_round[cols.keys()].copy()
    data_round.columns = cols.values()
    
    dict_position = {
        1: "GK",
        2: "FB",
        3: "CB",
        4: "MD",
        5: "AT",
        6: "HC",
    }
    data_round["position"] = data_round["position_id"].map(dict_position)
    data_round.drop("position_id", axis=1, inplace=True)
    
    data_round["round"] = num_round
    
    return data_round

# %%
# Use data from last round since it aggregates full season stats
data_25 = prepare_data(2025, 38)
data_25.head()
# Out:
#       id          name team  matches  pts_round  pts_avg_played  has_played  \
# 0  37281  Mano Menezes  GRE       31      10.67            5.43        True
# 1  37457     Léo Condé  CEA       35       4.09            4.98        True
# 2  37656         Fábio  FLU       36      11.50            4.33        True
# 3  37715  Thiago Silva  FLU       23      13.90            4.22        True
# 4  38913          Nenê  JUV       23       1.00            2.76        True
#
#   position  round
# 0       HC     38
# 1       HC     38
# 2       GK     38
# 3       CB     38
# 4       MD     38

# %%
data_all_25 = pd.DataFrame()
for round in range(1, 39):
    data_all_25 = pd.concat([data_all_25, prepare_data(2025, round)], ignore_index=True)
data_all_25.head()
# Out:
#       id            name team  matches  pts_round  pts_avg_played  has_played  \
# 0  37281    Mano Menezes  FLU        0        0.0             0.0       False
# 1  37457       Léo Condé  CEA        0        0.0             0.0       False
# 2  37656           Fábio  FLU        0        0.0             0.0       False
# 3  37715    Thiago Silva  FLU        0        0.0             0.0       False
# 4  38398  Renato Augusto  FLU        0        0.0             0.0       False
#
#   position  round
# 0       HC      1
# 1       HC      1
# 2       GK      1
# 3       CB      1
# 4       MD      1

# %%
def count_max_matches(player_id: int) -> int:
    return data_all_25[data_all_25["id"] == player_id]["matches"].count()

# %%
data_25["matches_max"] = data_25["id"].apply(count_max_matches)
data_25["availability"] = data_25["matches"] / data_25["matches_max"]
data_25.head(10)
# Out:
#       id            name team  matches  pts_round  pts_avg_played  has_played  \
# 0  37281    Mano Menezes  GRE       31      10.67            5.43        True
# 1  37457       Léo Condé  CEA       35       4.09            4.98        True
# 2  37656           Fábio  FLU       36      11.50            4.33        True
# 3  37715    Thiago Silva  FLU       23      13.90            4.22        True
# 4  38913            Nenê  JUV       23       1.00            2.76        True
# 5  39148            Hulk  CAM       27      19.20            6.19        True
# 6  39656     Alan Franco  CAM       26       1.20            2.38        True
# 7  39850  Vagner Mancini  RBB        5       3.04            4.26        True
# 8  40006      Abel Braga  INT        2       7.58            5.60        True
# 9  40990  Dorival Júnior  COR       32       4.65            5.11        True
#
#   position  round  matches_max  availability
# 0       HC     38           34      0.911765
# 1       HC     38           38      0.921053
# 2       GK     38           38      0.947368
# 3       CB     38           38      0.605263
# 4       MD     38           38      0.605263
# 5       AT     38           38      0.710526
# 6       MD     38           38      0.684211
# 7       HC     38            8      0.625000
# 8       HC     38            2      1.000000
# 9       HC     38           33      0.969697

# %%
def calculate_std_played(player_id: int) -> float:
    return data_all_25[data_all_25["id"] == player_id]["pts_avg_played"].std()

# %%
data_25["pts_std_played"] = data_25["id"].apply(calculate_std_played)
data_25.head(10)
# Out:
#       id            name team  matches  pts_round  pts_avg_played  has_played  \
# 0  37281    Mano Menezes  GRE       31      10.67            5.43        True
# 1  37457       Léo Condé  CEA       35       4.09            4.98        True
# 2  37656           Fábio  FLU       36      11.50            4.33        True
# 3  37715    Thiago Silva  FLU       23      13.90            4.22        True
# 4  38913            Nenê  JUV       23       1.00            2.76        True
# 5  39148            Hulk  CAM       27      19.20            6.19        True
# 6  39656     Alan Franco  CAM       26       1.20            2.38        True
# 7  39850  Vagner Mancini  RBB        5       3.04            4.26        True
# 8  40006      Abel Braga  INT        2       7.58            5.60        True
# 9  40990  Dorival Júnior  COR       32       4.65            5.11        True
#
#   position  round  matches_max  availability  pts_std_played
# 0       HC     38           34      0.911765        0.964043
# 1       HC     38           38      0.921053        1.082931
# 2       GK     38           38      0.947368        0.738093
# 3       CB     38           38      0.605263        0.864865
# 4       MD     38           38      0.605263        0.909614
# 5       AT     38           38      0.710526        1.132822
# 6       MD     38           38      0.684211        0.516080
# 7       HC     38            8      0.625000        0.853914
# 8       HC     38            2      1.000000        1.407142
# 9       HC     38           33      0.969697        1.055737

# %%
# Filter players who:
# - Played at least 5 matches
# - Availability higher than 30%
# - Are not head coaches
data_25 = data_25[(data_25["matches"] >= 5) & ((data_25["availability"] >= 0.3)) & (data_25["position"] != "HC")]
data_25.head()
# Out:
#       id          name team  matches  pts_round  pts_avg_played  has_played  \
# 2  37656         Fábio  FLU       36       11.5            4.33        True
# 3  37715  Thiago Silva  FLU       23       13.9            4.22        True
# 4  38913          Nenê  JUV       23        1.0            2.76        True
# 5  39148          Hulk  CAM       27       19.2            6.19        True
# 6  39656   Alan Franco  CAM       26        1.2            2.38        True
#
#   position  round  matches_max  availability  pts_std_played
# 2       GK     38           38      0.947368        0.738093
# 3       CB     38           38      0.605263        0.864865
# 4       MD     38           38      0.605263        0.909614
# 5       AT     38           38      0.710526        1.132822
# 6       MD     38           38      0.684211        0.516080

# %%
data_25["pts_avg_all"] = data_25["pts_avg_played"] * data_25["availability"]
data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  availability  pts_std_played  \
# 2         True       GK     38           38      0.947368        0.738093
# 3         True       CB     38           38      0.605263        0.864865
# 4         True       MD     38           38      0.605263        0.909614
# 5         True       AT     38           38      0.710526        1.132822
# 6         True       MD     38           38      0.684211        0.516080
# 11       False       AT     38           38      0.684211        0.720983
# 12       False       GK     38           38      0.921053        1.084309
# 14       False       GK     38           38      0.736842        2.741480
# 15        True       MD     38           38      0.789474        1.230944
# 16       False       AT     38           38      0.552632        0.942813
#
#     pts_avg_all
# 2      4.102105
# 3      2.554211
# 4      1.670526
# 5      4.398158
# 6      1.628421
# 11     1.170000
# 12     5.084211
# 14     4.841053
# 15     3.039474
# 16     1.132895

# %%
# Calculate value of each position for top players

# Average of top 10 players in each position
top10_means = data_25.groupby("position")["pts_avg_played"].apply(lambda x: x.nlargest(10).mean())
(top10_means - top10_means.mean()).sort_values(ascending=False)
# Out:
# position
# AT    0.9536
# FB    0.7906
# MD    0.0096
# GK   -0.6784
# CB   -1.0754
# Name: pts_avg_played, dtype: float64

# %%
# Calculate value of each position for top players

# Deviation of top 10 players in each position
top10_std = data_25.groupby("position")["pts_avg_played"].apply(lambda x: x.nlargest(10).std())
top10_std.sort_values(ascending=False)
# Out:
# position
# MD    1.318943
# GK    1.258522
# AT    1.203144
# FB    0.806391
# CB    0.318580
# Name: pts_avg_played, dtype: float64

# %%
# Calculate value of each position for general players

# Average of top 30 players in each position
top30_means = data_25.groupby("position")["pts_avg_played"].apply(lambda x: x.nlargest(30).mean())
(top30_means - top30_means.mean()).sort_values(ascending=False)
# Out:
# position
# FB    0.865400
# AT    0.559067
# MD   -0.234933
# CB   -0.510600
# GK   -0.678933
# Name: pts_avg_played, dtype: float64

# %%
# Calculate value of each position for general players

# Deviation of top 30 players in each position
top30_std = data_25.groupby("position")["pts_avg_played"].apply(lambda x: x.nlargest(30).std())
top30_std.sort_values(ascending=False)
# Out:
# position
# GK    1.376150
# AT    1.301418
# MD    1.244857
# FB    0.890872
# CB    0.491676
# Name: pts_avg_played, dtype: float64

# %%
# Number of players to compare per position
dict_num_players = {
    "GK": 10,
    "FB": 20,
    "CB": 20,
    "MD": 30,
    "AT": 30,
}

# %%
# Calculate mean and std of top X players per position
topX_means = data_25.groupby("position")["pts_avg_played"].apply(lambda x: x.nlargest(dict_num_players[x.name]).mean())
topX_stds = data_25.groupby("position")["pts_avg_played"].apply(lambda x: x.nlargest(dict_num_players[x.name]).std())

data_25["position__pts_avg_played"] = data_25["position"].map(topX_means)
data_25["position__pts_std_played"] = data_25["position"].map(topX_stds)

# Calculate z-score
data_25["pts_avg_played__vs_top_position"] = data_25["pts_avg_played"] - data_25["position__pts_avg_played"]
data_25["pts_z_played__vs_top_position"] = (data_25["pts_avg_played"] - data_25["position__pts_avg_played"]) / data_25["position__pts_std_played"]

data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  availability  pts_std_played  \
# 2         True       GK     38           38      0.947368        0.738093
# 3         True       CB     38           38      0.605263        0.864865
# 4         True       MD     38           38      0.605263        0.909614
# 5         True       AT     38           38      0.710526        1.132822
# 6         True       MD     38           38      0.684211        0.516080
# 11       False       AT     38           38      0.684211        0.720983
# 12       False       GK     38           38      0.921053        1.084309
# 14       False       GK     38           38      0.736842        2.741480
# 15        True       MD     38           38      0.789474        1.230944
# 16       False       AT     38           38      0.552632        0.942813
#
#     pts_avg_all  position__pts_avg_played  position__pts_std_played  \
# 2      4.102105                  5.541000                  1.258522
# 3      2.554211                  4.857000                  0.396818
# 4      1.670526                  4.877333                  1.244857
# 5      4.398158                  5.671333                  1.301418
# 6      1.628421                  4.877333                  1.244857
# 11     1.170000                  5.671333                  1.301418
# 12     5.084211                  5.541000                  1.258522
# 14     4.841053                  5.541000                  1.258522
# 15     3.039474                  4.877333                  1.244857
# 16     1.132895                  5.671333                  1.301418
#
#     pts_avg_played__vs_top_position  pts_z_played__vs_top_position
# 2                         -1.211000                      -0.962240
# 3                         -0.637000                      -1.605272
# 4                         -2.117333                      -1.700865
# 5                          0.518667                       0.398540
# 6                         -2.497333                      -2.006121
# 11                        -3.961333                      -3.043860
# 12                        -0.021000                      -0.016686
# 14                         1.029000                       0.817626
# 15                        -1.027333                      -0.825262
# 16                        -3.621333                      -2.782607

# %%
# Calculate mean and std of top X players per position
topX_means = data_25.groupby("position")["pts_avg_all"].apply(lambda x: x.nlargest(dict_num_players[x.name]).mean())
topX_stds = data_25.groupby("position")["pts_avg_all"].apply(lambda x: x.nlargest(dict_num_players[x.name]).std())

data_25["position__pts_avg_all"] = data_25["position"].map(topX_means)
data_25["position__pts_std_all"] = data_25["position"].map(topX_stds)

# Calculate z-score
data_25["pts_avg_all__vs_top_position"] = data_25["pts_avg_all"] - data_25["position__pts_avg_all"]
data_25["pts_z_all__vs_top_position"] = (data_25["pts_avg_all"] - data_25["position__pts_avg_all"]) / data_25["position__pts_std_all"]

data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  ...  pts_std_played  pts_avg_all  \
# 2         True       GK     38           38  ...        0.738093     4.102105
# 3         True       CB     38           38  ...        0.864865     2.554211
# 4         True       MD     38           38  ...        0.909614     1.670526
# 5         True       AT     38           38  ...        1.132822     4.398158
# 6         True       MD     38           38  ...        0.516080     1.628421
# 11       False       AT     38           38  ...        0.720983     1.170000
# 12       False       GK     38           38  ...        1.084309     5.084211
# 14       False       GK     38           38  ...        2.741480     4.841053
# 15        True       MD     38           38  ...        1.230944     3.039474
# 16       False       AT     38           38  ...        0.942813     1.132895
#
#     position__pts_avg_played  position__pts_std_played  \
# 2                   5.541000                  1.258522
# 3                   4.857000                  0.396818
# 4                   4.877333                  1.244857
# 5                   5.671333                  1.301418
# 6                   4.877333                  1.244857
# 11                  5.671333                  1.301418
# 12                  5.541000                  1.258522
# 14                  5.541000                  1.258522
# 15                  4.877333                  1.244857
# 16                  5.671333                  1.301418
#
#     pts_avg_played__vs_top_position  pts_z_played__vs_top_position  \
# 2                         -1.211000                      -0.962240
# 3                         -0.637000                      -1.605272
# 4                         -2.117333                      -1.700865
# 5                          0.518667                       0.398540
# 6                         -2.497333                      -2.006121
# 11                        -3.961333                      -3.043860
# 12                        -0.021000                      -0.016686
# 14                         1.029000                       0.817626
# 15                        -1.027333                      -0.825262
# 16                        -3.621333                      -2.782607
#
#     position__pts_avg_all  position__pts_std_all  \
# 2                4.161640               0.713226
# 3                3.313605               0.554797
# 4                3.597620               1.149005
# 5                4.358933               1.096716
# 6                3.597620               1.149005
# 11               4.358933               1.096716
# 12               4.161640               0.713226
# 14               4.161640               0.713226
# 15               3.597620               1.149005
# 16               4.358933               1.096716
#
#     pts_avg_all__vs_top_position  pts_z_all__vs_top_position
# 2                      -0.059535                   -0.083473
# 3                      -0.759395                   -1.368779
# 4                      -1.927094                   -1.677185
# 5                       0.039225                    0.035766
# 6                      -1.969199                   -1.713830
# 11                     -3.188933                   -2.907712
# 12                      0.922570                    1.293517
# 14                      0.679413                    0.952590
# 15                     -0.558147                   -0.485765
# 16                     -3.226038                   -2.941545
#
# [10 rows x 21 columns]

# %%
# Calculate mean and std of top 200 players
data_25["general__pts_avg_played"] = data_25["pts_avg_played"].nlargest(200).mean()
data_25["general__pts_std_played"] = data_25["pts_avg_played"].nlargest(200).std()

# Calculate z-score
data_25["pts_avg_played__vs_top_general"] = data_25["pts_avg_played"] - data_25["general__pts_avg_played"]
data_25["pts_z_played__vs_top_general"] = (data_25["pts_avg_played"] - data_25["general__pts_avg_played"]) / data_25["general__pts_std_played"]

data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  ...  \
# 2         True       GK     38           38  ...
# 3         True       CB     38           38  ...
# 4         True       MD     38           38  ...
# 5         True       AT     38           38  ...
# 6         True       MD     38           38  ...
# 11       False       AT     38           38  ...
# 12       False       GK     38           38  ...
# 14       False       GK     38           38  ...
# 15        True       MD     38           38  ...
# 16       False       AT     38           38  ...
#
#     pts_avg_played__vs_top_position  pts_z_played__vs_top_position  \
# 2                         -1.211000                      -0.962240
# 3                         -0.637000                      -1.605272
# 4                         -2.117333                      -1.700865
# 5                          0.518667                       0.398540
# 6                         -2.497333                      -2.006121
# 11                        -3.961333                      -3.043860
# 12                        -0.021000                      -0.016686
# 14                         1.029000                       0.817626
# 15                        -1.027333                      -0.825262
# 16                        -3.621333                      -2.782607
#
#     position__pts_avg_all  position__pts_std_all  \
# 2                4.161640               0.713226
# 3                3.313605               0.554797
# 4                3.597620               1.149005
# 5                4.358933               1.096716
# 6                3.597620               1.149005
# 11               4.358933               1.096716
# 12               4.161640               0.713226
# 14               4.161640               0.713226
# 15               3.597620               1.149005
# 16               4.358933               1.096716
#
#     pts_avg_all__vs_top_position  pts_z_all__vs_top_position  \
# 2                      -0.059535                   -0.083473
# 3                      -0.759395                   -1.368779
# 4                      -1.927094                   -1.677185
# 5                       0.039225                    0.035766
# 6                      -1.969199                   -1.713830
# 11                     -3.188933                   -2.907712
# 12                      0.922570                    1.293517
# 14                      0.679413                    0.952590
# 15                     -0.558147                   -0.485765
# 16                     -3.226038                   -2.941545
#
#     general__pts_avg_played  general__pts_std_played  \
# 2                   4.90055                  1.10607
# 3                   4.90055                  1.10607
# 4                   4.90055                  1.10607
# 5                   4.90055                  1.10607
# 6                   4.90055                  1.10607
# 11                  4.90055                  1.10607
# 12                  4.90055                  1.10607
# 14                  4.90055                  1.10607
# 15                  4.90055                  1.10607
# 16                  4.90055                  1.10607
#
#     pts_avg_played__vs_top_general  pts_z_played__vs_top_general
# 2                         -0.57055                     -0.515835
# 3                         -0.68055                     -0.615287
# 4                         -2.14055                     -1.935276
# 5                          1.28945                      1.165795
# 6                         -2.52055                     -2.278835
# 11                        -3.19055                     -2.884583
# 12                         0.61945                      0.560046
# 14                         1.66945                      1.509353
# 15                        -1.05055                     -0.949805
# 16                        -2.85055                     -2.577188
#
# [10 rows x 25 columns]

# %%
# Calculate mean and std of top 200 players
data_25["general__pts_avg_all"] = data_25["pts_avg_all"].nlargest(200).mean()
data_25["general__pts_std_all"] = data_25["pts_avg_all"].nlargest(200).std()

# Calculate z-score
data_25["pts_avg_all__vs_top_general"] = data_25["pts_avg_all"] - data_25["general__pts_avg_all"]
data_25["pts_z_all__vs_top_general"] = (data_25["pts_avg_all"] - data_25["general__pts_avg_all"]) / data_25["general__pts_std_all"]

data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  ...  \
# 2         True       GK     38           38  ...
# 3         True       CB     38           38  ...
# 4         True       MD     38           38  ...
# 5         True       AT     38           38  ...
# 6         True       MD     38           38  ...
# 11       False       AT     38           38  ...
# 12       False       GK     38           38  ...
# 14       False       GK     38           38  ...
# 15        True       MD     38           38  ...
# 16       False       AT     38           38  ...
#
#     pts_avg_all__vs_top_position  pts_z_all__vs_top_position  \
# 2                      -0.059535                   -0.083473
# 3                      -0.759395                   -1.368779
# 4                      -1.927094                   -1.677185
# 5                       0.039225                    0.035766
# 6                      -1.969199                   -1.713830
# 11                     -3.188933                   -2.907712
# 12                      0.922570                    1.293517
# 14                      0.679413                    0.952590
# 15                     -0.558147                   -0.485765
# 16                     -3.226038                   -2.941545
#
#     general__pts_avg_played  general__pts_std_played  \
# 2                   4.90055                  1.10607
# 3                   4.90055                  1.10607
# 4                   4.90055                  1.10607
# 5                   4.90055                  1.10607
# 6                   4.90055                  1.10607
# 11                  4.90055                  1.10607
# 12                  4.90055                  1.10607
# 14                  4.90055                  1.10607
# 15                  4.90055                  1.10607
# 16                  4.90055                  1.10607
#
#     pts_avg_played__vs_top_general  pts_z_played__vs_top_general  \
# 2                         -0.57055                     -0.515835
# 3                         -0.68055                     -0.615287
# 4                         -2.14055                     -1.935276
# 5                          1.28945                      1.165795
# 6                         -2.52055                     -2.278835
# 11                        -3.19055                     -2.884583
# 12                         0.61945                      0.560046
# 14                         1.66945                      1.509353
# 15                        -1.05055                     -0.949805
# 16                        -2.85055                     -2.577188
#
#     general__pts_avg_all  general__pts_std_all  pts_avg_all__vs_top_general  \
# 2               3.401697              1.082086                     0.700408
# 3               3.401697              1.082086                    -0.847486
# 4               3.401697              1.082086                    -1.731171
# 5               3.401697              1.082086                     0.996461
# 6               3.401697              1.082086                    -1.773276
# 11              3.401697              1.082086                    -2.231697
# 12              3.401697              1.082086                     1.682514
# 14              3.401697              1.082086                     1.439356
# 15              3.401697              1.082086                    -0.362223
# 16              3.401697              1.082086                    -2.268802
#
#     pts_z_all__vs_top_general
# 2                    0.647276
# 3                   -0.783197
# 4                   -1.599846
# 5                    0.920871
# 6                   -1.638757
# 11                  -2.062403
# 12                   1.554880
# 14                   1.330168
# 15                  -0.334745
# 16                  -2.096693
#
# [10 rows x 29 columns]

# %%
# Calculate Draft Value Score (DVS)

alpha = 0.6
beta = 0.4

data_25["dvs_position"] = (
    alpha * data_25["pts_z_played__vs_top_position"] +
    beta * data_25["pts_z_all__vs_top_position"]
)

data_25["dvs_general"] = (
    alpha * data_25["pts_z_played__vs_top_general"] +
    beta * data_25["pts_z_all__vs_top_general"]
)

data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  ...  general__pts_avg_played  \
# 2         True       GK     38           38  ...                  4.90055
# 3         True       CB     38           38  ...                  4.90055
# 4         True       MD     38           38  ...                  4.90055
# 5         True       AT     38           38  ...                  4.90055
# 6         True       MD     38           38  ...                  4.90055
# 11       False       AT     38           38  ...                  4.90055
# 12       False       GK     38           38  ...                  4.90055
# 14       False       GK     38           38  ...                  4.90055
# 15        True       MD     38           38  ...                  4.90055
# 16       False       AT     38           38  ...                  4.90055
#
#     general__pts_std_played  pts_avg_played__vs_top_general  \
# 2                   1.10607                        -0.57055
# 3                   1.10607                        -0.68055
# 4                   1.10607                        -2.14055
# 5                   1.10607                         1.28945
# 6                   1.10607                        -2.52055
# 11                  1.10607                        -3.19055
# 12                  1.10607                         0.61945
# 14                  1.10607                         1.66945
# 15                  1.10607                        -1.05055
# 16                  1.10607                        -2.85055
#
#     pts_z_played__vs_top_general  general__pts_avg_all  general__pts_std_all  \
# 2                      -0.515835              3.401697              1.082086
# 3                      -0.615287              3.401697              1.082086
# 4                      -1.935276              3.401697              1.082086
# 5                       1.165795              3.401697              1.082086
# 6                      -2.278835              3.401697              1.082086
# 11                     -2.884583              3.401697              1.082086
# 12                      0.560046              3.401697              1.082086
# 14                      1.509353              3.401697              1.082086
# 15                     -0.949805              3.401697              1.082086
# 16                     -2.577188              3.401697              1.082086
#
#     pts_avg_all__vs_top_general  pts_z_all__vs_top_general  dvs_position  \
# 2                      0.700408                   0.647276     -0.610733
# 3                     -0.847486                  -0.783197     -1.510675
# 4                     -1.731171                  -1.599846     -1.691393
# 5                      0.996461                   0.920871      0.253430
# 6                     -1.773276                  -1.638757     -1.889205
# 11                    -2.231697                  -2.062403     -2.989401
# 12                     1.682514                   1.554880      0.507395
# 14                     1.439356                   1.330168      0.871612
# 15                    -0.362223                  -0.334745     -0.689463
# 16                    -2.268802                  -2.096693     -2.846182
#
#     dvs_general
# 2     -0.050591
# 3     -0.682451
# 4     -1.801104
# 5      1.067825
# 6     -2.022804
# 11    -2.555711
# 12     0.957980
# 14     1.437679
# 15    -0.703781
# 16    -2.384990
#
# [10 rows x 31 columns]

# %%
# Calculate Adjusted DVS

data_25["risk"] = 1 - data_25["availability"]

gamma = 0.3  # less penalizing since we already consider availability in pts_avg_all

data_25["dvs_position_adj"] = data_25["dvs_position"] * (1 - data_25["risk"] * gamma)
data_25["dvs_general_adj"] = data_25["dvs_general"] * (1 - data_25["risk"] * gamma)

data_25.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 2   37656            Fábio  FLU       36       11.5            4.33
# 3   37715     Thiago Silva  FLU       23       13.9            4.22
# 4   38913             Nenê  JUV       23        1.0            2.76
# 5   39148             Hulk  CAM       27       19.2            6.19
# 6   39656      Alan Franco  CAM       26        1.2            2.38
# 11  42222          Osvaldo  VIT       26        0.0            1.71
# 12  42234           Cássio  CRU       35        0.0            5.52
# 14  51413           Walter  MIR       28        0.0            6.57
# 15  51772  Everton Ribeiro  BAH       30        1.7            3.85
# 16  61188         Gilberto  JUV       21        0.0            2.05
#
#     has_played position  round  matches_max  ...  \
# 2         True       GK     38           38  ...
# 3         True       CB     38           38  ...
# 4         True       MD     38           38  ...
# 5         True       AT     38           38  ...
# 6         True       MD     38           38  ...
# 11       False       AT     38           38  ...
# 12       False       GK     38           38  ...
# 14       False       GK     38           38  ...
# 15        True       MD     38           38  ...
# 16       False       AT     38           38  ...
#
#     pts_z_played__vs_top_general  general__pts_avg_all  general__pts_std_all  \
# 2                      -0.515835              3.401697              1.082086
# 3                      -0.615287              3.401697              1.082086
# 4                      -1.935276              3.401697              1.082086
# 5                       1.165795              3.401697              1.082086
# 6                      -2.278835              3.401697              1.082086
# 11                     -2.884583              3.401697              1.082086
# 12                      0.560046              3.401697              1.082086
# 14                      1.509353              3.401697              1.082086
# 15                     -0.949805              3.401697              1.082086
# 16                     -2.577188              3.401697              1.082086
#
#     pts_avg_all__vs_top_general  pts_z_all__vs_top_general  dvs_position  \
# 2                      0.700408                   0.647276     -0.610733
# 3                     -0.847486                  -0.783197     -1.510675
# 4                     -1.731171                  -1.599846     -1.691393
# 5                      0.996461                   0.920871      0.253430
# 6                     -1.773276                  -1.638757     -1.889205
# 11                    -2.231697                  -2.062403     -2.989401
# 12                     1.682514                   1.554880      0.507395
# 14                     1.439356                   1.330168      0.871612
# 15                    -0.362223                  -0.334745     -0.689463
# 16                    -2.268802                  -2.096693     -2.846182
#
#     dvs_general      risk  dvs_position_adj  dvs_general_adj
# 2     -0.050591  0.052632         -0.601090        -0.049792
# 3     -0.682451  0.394737         -1.331779        -0.601634
# 4     -1.801104  0.394737         -1.491096        -1.587815
# 5      1.067825  0.289474          0.231422         0.975093
# 6     -2.022804  0.315789         -1.710227        -1.831170
# 11    -2.555711  0.315789         -2.706194        -2.313591
# 12     0.957980  0.078947          0.495378         0.935291
# 14     1.437679  0.263158          0.802800         1.324178
# 15    -0.703781  0.210526         -0.645918        -0.659332
# 16    -2.384990  0.447368         -2.464194        -2.064900
#
# [10 rows x 34 columns]

# %%
# Ranking players per position based on adjusted position DVS
data_25["adp_position"] = data_25.groupby("position")["dvs_position_adj"].rank(ascending=False, method="min").astype(int)
data_25.sort_values(by=["dvs_position_adj"], ascending=False).head(20)
# Out:
#          id             name team  matches  pts_round  pts_avg_played  \
# 161   87863       Arrascaeta  FLA       32        0.0            9.32
# 359  103445       Kaio Jorge  CRU       33        0.0            9.46
# 514  114802      Vitor Roque  PAL       31        0.0            8.31
# 258   96610  Matheus Pereira  CRU       34        0.0            7.03
# 85    78850         Reinaldo  MIR       32        0.0            7.94
# 398  105300        Ferraresi  SAO       23        0.0            5.99
# 497  112709      Kaiki Bruno  CRU       34        0.0            7.34
# 425  106708     Igor Formiga  JUV       16        6.3            7.47
# 565  122486            Rayan  VAS       32        0.0            7.30
# 423  106593         Villalba  CRU       32        0.0            5.21
# 229   93716   Paulo Henrique  VAS       26        0.0            7.82
# 176   89275          William  CRU       30        0.0            7.39
# 611  126471          Barreal  SAN       33        6.0            5.93
# 24    68685     Alan Patrick  INT       30        8.7            6.16
# 19    63007           Neymar  SAN       19        3.3            7.25
# 403  105563  Carlos Vinícius  GRE       13       15.6            7.97
# 504  113103      Flaco López  PAL       30       10.4            6.80
# 14    51413           Walter  MIR       28        0.0            6.57
# 241   94583            Pedro  FLA       21        0.0            7.74
# 195   90768   Fabrício Bruno  CRU       33        0.0            4.89
#
#      has_played position  round  matches_max  ...  general__pts_avg_all  \
# 161       False       MD     38           38  ...              3.401697
# 359       False       AT     38           38  ...              3.401697
# 514       False       AT     38           38  ...              3.401697
# 258       False       MD     38           38  ...              3.401697
# 85        False       FB     38           38  ...              3.401697
# 398       False       CB     38           38  ...              3.401697
# 497       False       FB     38           38  ...              3.401697
# 425        True       FB     38           19  ...              3.401697
# 565       False       AT     38           38  ...              3.401697
# 423       False       CB     38           38  ...              3.401697
# 229       False       FB     38           38  ...              3.401697
# 176       False       FB     38           38  ...              3.401697
# 611        True       MD     38           38  ...              3.401697
# 24         True       MD     38           38  ...              3.401697
# 19         True       MD     38           38  ...              3.401697
# 403        True       AT     38           23  ...              3.401697
# 504        True       AT     38           38  ...              3.401697
# 14        False       GK     38           38  ...              3.401697
# 241       False       AT     38           38  ...              3.401697
# 195       False       CB     38           38  ...              3.401697
#
#      general__pts_std_all  pts_avg_all__vs_top_general  \
# 161              1.082086                     4.446724
# 359              1.082086                     4.813566
# 514              1.082086                     3.377514
# 258              1.082086                     2.888303
# 85               1.082086                     3.284619
# 398              1.082086                     0.223829
# 497              1.082086                     3.165672
# 425              1.082086                     2.888829
# 565              1.082086                     2.745672
# 423              1.082086                     0.985672
# 229              1.082086                     1.948829
# 176              1.082086                     2.432514
# 611              1.082086                     1.748040
# 24               1.082086                     1.461461
# 19               1.082086                     0.223303
# 403              1.082086                     1.103086
# 504              1.082086                     1.966724
# 14               1.082086                     1.439356
# 241              1.082086                     0.875672
# 195              1.082086                     0.844882
#
#      pts_z_all__vs_top_general  dvs_position  dvs_general      risk  \
# 161                   4.109401      3.621110     4.041141  0.157895
# 359                   4.448415      3.153212     4.252691  0.131579
# 514                   3.121299      2.099256     3.098014  0.184211
# 258                   2.669200      1.974840     2.222824  0.105263
# 85                    3.035451      1.941910     2.862965  0.157895
# 398                   0.206850      1.938020     0.673724  0.394737
# 497                   2.925527      1.484969     2.493518  0.105263
# 425                   2.669686      1.451088     2.461702  0.157895
# 565                   2.537388      1.403161     2.316564  0.157895
# 423                   0.910900      1.307913     0.532224  0.157895
# 229                   1.800993      1.274391     2.304086  0.315789
# 176                   2.247986      1.196747     2.249625  0.210526
# 611                   1.615436      1.047702     1.204611  0.131579
# 24                    1.350596      1.058792     1.223441  0.210526
# 19                    0.206364      1.153117     1.357031  0.500000
# 403                   1.019407      1.112963     2.072821  0.434783
# 504                   1.817531      0.888542     1.757390  0.210526
# 14                    1.330168      0.871612     1.437679  0.263158
# 241                   0.809244      0.923981     1.863989  0.447368
# 195                   0.780790      0.722557     0.306593  0.131579
#
#      dvs_position_adj  dvs_general_adj  adp_position
# 161          3.449584         3.849718             1
# 359          3.028743         4.084822             1
# 514          1.983245         2.926808             2
# 258          1.912477         2.152630             2
# 85           1.849925         2.727350             1
# 398          1.708518         0.593941             1
# 497          1.438075         2.414775             2
# 425          1.382352         2.345095             3
# 565          1.336696         2.206832             3
# 423          1.245959         0.507014             2
# 229          1.153659         2.085804             4
# 176          1.121163         2.107543             5
# 611          1.006345         1.157061             3
# 24           0.991921         1.146171             4
# 19           0.980149         1.153476             5
# 403          0.967794         1.802453             4
# 504          0.832423         1.646397             5
# 14           0.802800         1.324178             1
# 241          0.799973         1.613822             6
# 195          0.694035         0.294491             3
#
# [20 rows x 35 columns]

# %%
# Ranking all players based on adjusted general DVS
data_25["adp_general"] = data_25["dvs_general_adj"].rank(ascending=False, method="min").astype(int)
data_25.sort_values(by="dvs_general_adj", ascending=False).head(20)
# Out:
#          id             name team  matches  pts_round  pts_avg_played  \
# 359  103445       Kaio Jorge  CRU       33        0.0            9.46
# 161   87863       Arrascaeta  FLA       32        0.0            9.32
# 514  114802      Vitor Roque  PAL       31        0.0            8.31
# 85    78850         Reinaldo  MIR       32        0.0            7.94
# 497  112709      Kaiki Bruno  CRU       34        0.0            7.34
# 425  106708     Igor Formiga  JUV       16        6.3            7.47
# 565  122486            Rayan  VAS       32        0.0            7.30
# 258   96610  Matheus Pereira  CRU       34        0.0            7.03
# 176   89275          William  CRU       30        0.0            7.39
# 229   93716   Paulo Henrique  VAS       26        0.0            7.82
# 403  105563  Carlos Vinícius  GRE       13       15.6            7.97
# 504  113103      Flaco López  PAL       30       10.4            6.80
# 241   94583            Pedro  FLA       21        0.0            7.74
# 370  104084    Carlos Miguel  PAL        6        0.0            8.52
# 292   98873      Samuel Lino  FLA       19        0.0            6.05
# 14    51413           Walter  MIR       28        0.0            6.57
# 237   94207        Guilherme  SAN       31       20.2            6.27
# 611  126471          Barreal  SAN       33        6.0            5.93
# 19    63007           Neymar  SAN       19        3.3            7.25
# 24    68685     Alan Patrick  INT       30        8.7            6.16
#
#      has_played position  round  matches_max  ...  general__pts_std_all  \
# 359       False       AT     38           38  ...              1.082086
# 161       False       MD     38           38  ...              1.082086
# 514       False       AT     38           38  ...              1.082086
# 85        False       FB     38           38  ...              1.082086
# 497       False       FB     38           38  ...              1.082086
# 425        True       FB     38           19  ...              1.082086
# 565       False       AT     38           38  ...              1.082086
# 258       False       MD     38           38  ...              1.082086
# 176       False       FB     38           38  ...              1.082086
# 229       False       FB     38           38  ...              1.082086
# 403        True       AT     38           23  ...              1.082086
# 504        True       AT     38           38  ...              1.082086
# 241       False       AT     38           38  ...              1.082086
# 370       False       GK     38           19  ...              1.082086
# 292       False       AT     38           21  ...              1.082086
# 14        False       GK     38           38  ...              1.082086
# 237        True       AT     38           38  ...              1.082086
# 611        True       MD     38           38  ...              1.082086
# 19         True       MD     38           38  ...              1.082086
# 24         True       MD     38           38  ...              1.082086
#
#      pts_avg_all__vs_top_general  pts_z_all__vs_top_general  dvs_position  \
# 359                     4.813566                   4.448415      3.153212
# 161                     4.446724                   4.109401      3.621110
# 514                     3.377514                   3.121299      2.099256
# 85                      3.284619                   3.035451      1.941910
# 497                     3.165672                   2.925527      1.484969
# 425                     2.888829                   2.669686      1.451088
# 565                     2.745672                   2.537388      1.403161
# 258                     2.888303                   2.669200      1.974840
# 176                     2.432514                   2.247986      1.196747
# 229                     1.948829                   1.800993      1.274391
# 403                     1.103086                   1.019407      1.112963
# 504                     1.966724                   1.817531      0.888542
# 241                     0.875672                   0.809244      0.923981
# 370                    -0.711171                  -0.657222      0.595190
# 292                     2.072113                   1.914925      0.581203
# 14                      1.439356                   1.330168      0.871612
# 237                     1.713303                   1.583334      0.551764
# 611                     1.748040                   1.615436      1.047702
# 19                      0.223303                   0.206364      1.153117
# 24                      1.461461                   1.350596      1.058792
#
#      dvs_general      risk  dvs_position_adj  dvs_general_adj  adp_position  \
# 359     4.252691  0.131579          3.028743         4.084822             1
# 161     4.041141  0.157895          3.449584         3.849718             1
# 514     3.098014  0.184211          1.983245         2.926808             2
# 85      2.862965  0.157895          1.849925         2.727350             1
# 497     2.493518  0.105263          1.438075         2.414775             2
# 425     2.461702  0.157895          1.382352         2.345095             3
# 565     2.316564  0.157895          1.336696         2.206832             3
# 258     2.222824  0.105263          1.912477         2.152630             2
# 176     2.249625  0.210526          1.121163         2.107543             5
# 229     2.304086  0.315789          1.153659         2.085804             4
# 403     2.072821  0.434783          0.967794         1.802453             4
# 504     1.757390  0.210526          0.832423         1.646397             5
# 241     1.863989  0.447368          0.799973         1.613822             6
# 370     1.700523  0.684211          0.473020         1.351468             4
# 292     1.389502  0.095238          0.564597         1.349802             7
# 14      1.437679  0.263158          0.802800         1.324178             1
# 237     1.376207  0.184211          0.521272         1.300154             8
# 611     1.204611  0.131579          1.006345         1.157061             3
# 19      1.357031  0.500000          0.980149         1.153476             5
# 24      1.223441  0.210526          0.991921         1.146171             4
#
#      adp_general
# 359            1
# 161            2
# 514            3
# 85             4
# 497            5
# 425            6
# 565            7
# 258            8
# 176            9
# 229           10
# 403           11
# 504           12
# 241           13
# 370           14
# 292           15
# 14            16
# 237           17
# 611           18
# 19            19
# 24            20
#
# [20 rows x 36 columns]

# %%
data_25 = data_25[
    [
        "id",
        "name",
        "team",
        "position",
        "matches",
        "availability",
        "pts_avg_played",
        "pts_avg_all",
        "pts_std_played",
        "adp_position",
        "dvs_position_adj",
        "dvs_position",
        "pts_z_played__vs_top_position",
        "pts_z_all__vs_top_position",
        "pts_avg_played__vs_top_position",
        "pts_avg_all__vs_top_position",
        "adp_general",
        "dvs_general_adj",
        "dvs_general",
        "pts_z_played__vs_top_general",
        "pts_z_all__vs_top_general",
        "pts_avg_played__vs_top_general",
        "pts_avg_all__vs_top_general",
    ]
]
data_25.head(10)
# Out:
#        id             name team position  matches  availability  \
# 2   37656            Fábio  FLU       GK       36      0.947368
# 3   37715     Thiago Silva  FLU       CB       23      0.605263
# 4   38913             Nenê  JUV       MD       23      0.605263
# 5   39148             Hulk  CAM       AT       27      0.710526
# 6   39656      Alan Franco  CAM       MD       26      0.684211
# 11  42222          Osvaldo  VIT       AT       26      0.684211
# 12  42234           Cássio  CRU       GK       35      0.921053
# 14  51413           Walter  MIR       GK       28      0.736842
# 15  51772  Everton Ribeiro  BAH       MD       30      0.789474
# 16  61188         Gilberto  JUV       AT       21      0.552632
#
#     pts_avg_played  pts_avg_all  pts_std_played  adp_position  ...  \
# 2             4.33     4.102105        0.738093             8  ...
# 3             4.22     2.554211        0.864865            23  ...
# 4             2.76     1.670526        0.909614            67  ...
# 5             6.19     4.398158        1.132822             9  ...
# 6             2.38     1.628421        0.516080            85  ...
# 11            1.71     1.170000        0.720983           117  ...
# 12            5.52     5.084211        1.084309             3  ...
# 14            6.57     4.841053        2.741480             1  ...
# 15            3.85     3.039474        1.230944            27  ...
# 16            2.05     1.132895        0.942813           103  ...
#
#     pts_z_all__vs_top_position  pts_avg_played__vs_top_position  \
# 2                    -0.083473                        -1.211000
# 3                    -1.368779                        -0.637000
# 4                    -1.677185                        -2.117333
# 5                     0.035766                         0.518667
# 6                    -1.713830                        -2.497333
# 11                   -2.907712                        -3.961333
# 12                    1.293517                        -0.021000
# 14                    0.952590                         1.029000
# 15                   -0.485765                        -1.027333
# 16                   -2.941545                        -3.621333
#
#     pts_avg_all__vs_top_position  adp_general  dvs_general_adj  dvs_general  \
# 2                      -0.059535           76        -0.049792    -0.050591
# 3                      -0.759395          148        -0.601634    -0.682451
# 4                      -1.927094          293        -1.587815    -1.801104
# 5                       0.039225           23         0.975093     1.067825
# 6                      -1.969199          331        -1.831170    -2.022804
# 11                     -3.188933          401        -2.313591    -2.555711
# 12                      0.922570           24         0.935291     0.957980
# 14                      0.679413           16         1.324178     1.437679
# 15                     -0.558147          161        -0.659332    -0.703781
# 16                     -3.226038          363        -2.064900    -2.384990
#
#     pts_z_played__vs_top_general  pts_z_all__vs_top_general  \
# 2                      -0.515835                   0.647276
# 3                      -0.615287                  -0.783197
# 4                      -1.935276                  -1.599846
# 5                       1.165795                   0.920871
# 6                      -2.278835                  -1.638757
# 11                     -2.884583                  -2.062403
# 12                      0.560046                   1.554880
# 14                      1.509353                   1.330168
# 15                     -0.949805                  -0.334745
# 16                     -2.577188                  -2.096693
#
#     pts_avg_played__vs_top_general  pts_avg_all__vs_top_general
# 2                         -0.57055                     0.700408
# 3                         -0.68055                    -0.847486
# 4                         -2.14055                    -1.731171
# 5                          1.28945                     0.996461
# 6                         -2.52055                    -1.773276
# 11                        -3.19055                    -2.231697
# 12                         0.61945                     1.682514
# 14                         1.66945                     1.439356
# 15                        -1.05055                    -0.362223
# 16                        -2.85055                    -2.268802
#
# [10 rows x 23 columns]

# %%
# Load data for 2026 season
data_26_start = prepare_data(2026, 1)
data_26_start.head(10)
# Out:
#       id            name team  matches  pts_round  pts_avg_played  has_played  \
# 0  37656           Fábio  FLU        1       2.10            2.10        True
# 1  39148            Hulk  CAM        1       5.30            5.30        True
# 2  39656     Alan Franco  CAM        1      -0.10           -0.10        True
# 3  39850  Vagner Mancini  RBB        1       8.07            8.07        True
# 4  40990  Dorival Júnior  COR        1       6.60            6.60        True
# 5  42135         Willian  GRE        1      -0.30           -0.30        True
# 6  42222         Osvaldo  VIT        1       0.80            0.80        True
# 7  42234          Cássio  CRU        1      -2.70           -2.70        True
# 8  42500          Fagner  CRU        1       0.90            0.90        True
# 9  45125            Tite  CRU        1       1.37            1.37        True
#
#   position  round
# 0       GK      1
# 1       AT      1
# 2       MD      1
# 3       HC      1
# 4       HC      1
# 5       MD      1
# 6       AT      1
# 7       GK      1
# 8       FB      1
# 9       HC      1

# %%
# Remove head coaches
data_26_start = data_26_start[data_26_start["position"] != "HC"]
data_26_start.head(10)
# Out:
#        id             name team  matches  pts_round  pts_avg_played  \
# 0   37656            Fábio  FLU        1        2.1             2.1
# 1   39148             Hulk  CAM        1        5.3             5.3
# 2   39656      Alan Franco  CAM        1       -0.1            -0.1
# 5   42135          Willian  GRE        1       -0.3            -0.3
# 6   42222          Osvaldo  VIT        1        0.8             0.8
# 7   42234           Cássio  CRU        1       -2.7            -2.7
# 8   42500           Fagner  CRU        1        0.9             0.9
# 10  50742    Gabriel Leite  CFC        0        0.0             0.0
# 11  51413           Walter  MIR        1        4.2             4.2
# 12  51772  Everton Ribeiro  BAH        1        1.5             1.5
#
#     has_played position  round
# 0         True       GK      1
# 1         True       AT      1
# 2         True       MD      1
# 5         True       MD      1
# 6         True       AT      1
# 7         True       GK      1
# 8         True       FB      1
# 10       False       GK      1
# 11        True       GK      1
# 12        True       MD      1

# %%
# Remove unused columns
data_26_start = data_26_start[["id", "name", "team", "position"]]
data_26_start.head(10)
# Out:
#        id             name team position
# 0   37656            Fábio  FLU       GK
# 1   39148             Hulk  CAM       AT
# 2   39656      Alan Franco  CAM       MD
# 5   42135          Willian  GRE       MD
# 6   42222          Osvaldo  VIT       AT
# 7   42234           Cássio  CRU       GK
# 8   42500           Fagner  CRU       FB
# 10  50742    Gabriel Leite  CFC       GK
# 11  51413           Walter  MIR       GK
# 12  51772  Everton Ribeiro  BAH       MD

# %%
# Merge 2025 and 2026 data, leaving new players blank
data = pd.merge(left=data_26_start, right=data_25, how="left", on="id", suffixes=("", "_25"))
data.head(10)
# Out:
#       id             name team position          name_25 team_25 position_25  \
# 0  37656            Fábio  FLU       GK            Fábio     FLU          GK
# 1  39148             Hulk  CAM       AT             Hulk     CAM          AT
# 2  39656      Alan Franco  CAM       MD      Alan Franco     CAM          MD
# 3  42135          Willian  GRE       MD              NaN     NaN         NaN
# 4  42222          Osvaldo  VIT       AT          Osvaldo     VIT          AT
# 5  42234           Cássio  CRU       GK           Cássio     CRU          GK
# 6  42500           Fagner  CRU       FB              NaN     NaN         NaN
# 7  50742    Gabriel Leite  CFC       GK              NaN     NaN         NaN
# 8  51413           Walter  MIR       GK           Walter     MIR          GK
# 9  51772  Everton Ribeiro  BAH       MD  Everton Ribeiro     BAH          MD
#
#    matches  availability  pts_avg_played  ...  pts_z_all__vs_top_position  \
# 0     36.0      0.947368            4.33  ...                   -0.083473
# 1     27.0      0.710526            6.19  ...                    0.035766
# 2     26.0      0.684211            2.38  ...                   -1.713830
# 3      NaN           NaN             NaN  ...                         NaN
# 4     26.0      0.684211            1.71  ...                   -2.907712
# 5     35.0      0.921053            5.52  ...                    1.293517
# 6      NaN           NaN             NaN  ...                         NaN
# 7      NaN           NaN             NaN  ...                         NaN
# 8     28.0      0.736842            6.57  ...                    0.952590
# 9     30.0      0.789474            3.85  ...                   -0.485765
#
#    pts_avg_played__vs_top_position  pts_avg_all__vs_top_position  adp_general  \
# 0                        -1.211000                     -0.059535         76.0
# 1                         0.518667                      0.039225         23.0
# 2                        -2.497333                     -1.969199        331.0
# 3                              NaN                           NaN          NaN
# 4                        -3.961333                     -3.188933        401.0
# 5                        -0.021000                      0.922570         24.0
# 6                              NaN                           NaN          NaN
# 7                              NaN                           NaN          NaN
# 8                         1.029000                      0.679413         16.0
# 9                        -1.027333                     -0.558147        161.0
#
#    dvs_general_adj  dvs_general  pts_z_played__vs_top_general  \
# 0        -0.049792    -0.050591                     -0.515835
# 1         0.975093     1.067825                      1.165795
# 2        -1.831170    -2.022804                     -2.278835
# 3              NaN          NaN                           NaN
# 4        -2.313591    -2.555711                     -2.884583
# 5         0.935291     0.957980                      0.560046
# 6              NaN          NaN                           NaN
# 7              NaN          NaN                           NaN
# 8         1.324178     1.437679                      1.509353
# 9        -0.659332    -0.703781                     -0.949805
#
#    pts_z_all__vs_top_general  pts_avg_played__vs_top_general  \
# 0                   0.647276                        -0.57055
# 1                   0.920871                         1.28945
# 2                  -1.638757                        -2.52055
# 3                        NaN                             NaN
# 4                  -2.062403                        -3.19055
# 5                   1.554880                         0.61945
# 6                        NaN                             NaN
# 7                        NaN                             NaN
# 8                   1.330168                         1.66945
# 9                  -0.334745                        -1.05055
#
#    pts_avg_all__vs_top_general
# 0                     0.700408
# 1                     0.996461
# 2                    -1.773276
# 3                          NaN
# 4                    -2.231697
# 5                     1.682514
# 6                          NaN
# 7                          NaN
# 8                     1.439356
# 9                    -0.362223
#
# [10 rows x 26 columns]

# %%
# Removing duplicate columns
data.drop([col for col in data.columns if col.endswith("_25")], axis=1, inplace=True)
data.head(10)
# Out:
#       id             name team position  matches  availability  \
# 0  37656            Fábio  FLU       GK     36.0      0.947368
# 1  39148             Hulk  CAM       AT     27.0      0.710526
# 2  39656      Alan Franco  CAM       MD     26.0      0.684211
# 3  42135          Willian  GRE       MD      NaN           NaN
# 4  42222          Osvaldo  VIT       AT     26.0      0.684211
# 5  42234           Cássio  CRU       GK     35.0      0.921053
# 6  42500           Fagner  CRU       FB      NaN           NaN
# 7  50742    Gabriel Leite  CFC       GK      NaN           NaN
# 8  51413           Walter  MIR       GK     28.0      0.736842
# 9  51772  Everton Ribeiro  BAH       MD     30.0      0.789474
#
#    pts_avg_played  pts_avg_all  pts_std_played  adp_position  ...  \
# 0            4.33     4.102105        0.738093           8.0  ...
# 1            6.19     4.398158        1.132822           9.0  ...
# 2            2.38     1.628421        0.516080          85.0  ...
# 3             NaN          NaN             NaN           NaN  ...
# 4            1.71     1.170000        0.720983         117.0  ...
# 5            5.52     5.084211        1.084309           3.0  ...
# 6             NaN          NaN             NaN           NaN  ...
# 7             NaN          NaN             NaN           NaN  ...
# 8            6.57     4.841053        2.741480           1.0  ...
# 9            3.85     3.039474        1.230944          27.0  ...
#
#    pts_z_all__vs_top_position  pts_avg_played__vs_top_position  \
# 0                   -0.083473                        -1.211000
# 1                    0.035766                         0.518667
# 2                   -1.713830                        -2.497333
# 3                         NaN                              NaN
# 4                   -2.907712                        -3.961333
# 5                    1.293517                        -0.021000
# 6                         NaN                              NaN
# 7                         NaN                              NaN
# 8                    0.952590                         1.029000
# 9                   -0.485765                        -1.027333
#
#    pts_avg_all__vs_top_position  adp_general  dvs_general_adj  dvs_general  \
# 0                     -0.059535         76.0        -0.049792    -0.050591
# 1                      0.039225         23.0         0.975093     1.067825
# 2                     -1.969199        331.0        -1.831170    -2.022804
# 3                           NaN          NaN              NaN          NaN
# 4                     -3.188933        401.0        -2.313591    -2.555711
# 5                      0.922570         24.0         0.935291     0.957980
# 6                           NaN          NaN              NaN          NaN
# 7                           NaN          NaN              NaN          NaN
# 8                      0.679413         16.0         1.324178     1.437679
# 9                     -0.558147        161.0        -0.659332    -0.703781
#
#    pts_z_played__vs_top_general  pts_z_all__vs_top_general  \
# 0                     -0.515835                   0.647276
# 1                      1.165795                   0.920871
# 2                     -2.278835                  -1.638757
# 3                           NaN                        NaN
# 4                     -2.884583                  -2.062403
# 5                      0.560046                   1.554880
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                      1.509353                   1.330168
# 9                     -0.949805                  -0.334745
#
#    pts_avg_played__vs_top_general  pts_avg_all__vs_top_general
# 0                        -0.57055                     0.700408
# 1                         1.28945                     0.996461
# 2                        -2.52055                    -1.773276
# 3                             NaN                          NaN
# 4                        -3.19055                    -2.231697
# 5                         0.61945                     1.682514
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                         1.66945                     1.439356
# 9                        -1.05055                    -0.362223
#
# [10 rows x 23 columns]

# %%
# data.to_excel("draft-board__new.xlsx", engine="openpyxl")

# %%
data_all_26 = pd.DataFrame()
for round in range(1, 2):
    data_all_26 = pd.concat([data_all_26, prepare_data(2026, round)], ignore_index=True)
data_all_26.head()
# Out:
#       id            name team  matches  pts_round  pts_avg_played  has_played  \
# 0  37656           Fábio  FLU        1       2.10            2.10        True
# 1  39148            Hulk  CAM        1       5.30            5.30        True
# 2  39656     Alan Franco  CAM        1      -0.10           -0.10        True
# 3  39850  Vagner Mancini  RBB        1       8.07            8.07        True
# 4  40990  Dorival Júnior  COR        1       6.60            6.60        True
#
#   position  round
# 0       GK      1
# 1       AT      1
# 2       MD      1
# 3       HC      1
# 4       HC      1

# %%
def avg_last_n_matches(player_id: int, n: int) -> float:
    player_data = data_all_26[(data_all_26["id"] == player_id) & (data_all_26["has_played"])].sort_values(by="round", ascending=False)
    return player_data["pts_round"].head(n).mean()

# %%
def std_last_n_matches(player_id: int, n: int) -> float:
    player_data = data_all_26[(data_all_26["id"] == player_id) & (data_all_26["has_played"])].sort_values(by="round", ascending=False)
    return player_data["pts_round"].head(n).std()

# %%
def count_played_in_last_n_matches(player_id: int, n: int) -> int:
    player_data = data_all_26[data_all_26["id"] == player_id].sort_values(by="round", ascending=False).head(n)
    return player_data["has_played"].sum()

# %%
data_26 = data_all_26.groupby("id").agg(
    {
        "name": "first",
        "team": "first",
        "position": "first",
    }
).reset_index()
data_26.head(10)
# Out:
#       id            name team position
# 0  37656           Fábio  FLU       GK
# 1  39148            Hulk  CAM       AT
# 2  39656     Alan Franco  CAM       MD
# 3  39850  Vagner Mancini  RBB       HC
# 4  40990  Dorival Júnior  COR       HC
# 5  42135         Willian  GRE       MD
# 6  42222         Osvaldo  VIT       AT
# 7  42234          Cássio  CRU       GK
# 8  42500          Fagner  CRU       FB
# 9  45125            Tite  CRU       HC

# %%
data_26["pts_avg_played__last_3"] = data_26["id"].apply(lambda idx: avg_last_n_matches(idx, 3))
data_26["pts_std_played__last_3"] = data_26["id"].apply(lambda idx: std_last_n_matches(idx, 3))

data_26["pts_avg_played__last_5"] = data_26["id"].apply(lambda idx: avg_last_n_matches(idx, 5))
data_26["pts_std_played__last_5"] = data_26["id"].apply(lambda idx: std_last_n_matches(idx, 5))

data_26["pts_avg_played__last_10"] = data_26["id"].apply(lambda idx: avg_last_n_matches(idx, 10))
data_26["pts_std_played__last_10"] = data_26["id"].apply(lambda idx: std_last_n_matches(idx, 10))

data_26["matches_played_in_last_5"] = data_26["id"].apply(lambda idx: count_played_in_last_n_matches(idx, 5))

data_26.head(10)
# Out:
#        id               name team position  pts_avg_played__last_3  \
# 0   37656              Fábio  FLU       GK                    2.10
# 1   39148               Hulk  CAM       AT                    5.30
# 2   39656        Alan Franco  CAM       MD                   -0.10
# 3   39850     Vagner Mancini  RBB       HC                    8.07
# 4   40990     Dorival Júnior  COR       HC                    6.60
# 5   42135            Willian  GRE       MD                   -0.30
# 6   42222            Osvaldo  VIT       AT                    0.80
# 7   42234             Cássio  CRU       GK                   -2.70
# 8   42500             Fagner  CRU       FB                    0.90
# 9   45125               Tite  CRU       HC                    1.37
# 10  50742      Gabriel Leite  CFC       GK                     NaN
# 11  51413             Walter  MIR       GK                    4.20
# 12  51772    Everton Ribeiro  BAH       MD                    1.50
# 13  61987        Alex Sandro  FLA       FB                    1.00
# 14  62977              Ganso  FLU       MD                   -0.30
# 15  63007             Neymar  SAN       MD                     NaN
# 16  63008       Rafael Tolói  SAO       CB                     NaN
# 17  63013       Marcos Rocha  GRE       FB                    0.00
# 18  63289          Edenílson  GRE       MD                    2.50
# 19  63354     Rodrigo Moledo  CFC       CB                     NaN
# 20  68685       Alan Patrick  INT       MD                    3.00
# 21  68708            Eduardo  MIR       MD                    7.00
# 22  68806               Neto  BOT       GK                   10.20
# 23  68822      Rafael Santos  CHA       GK                     NaN
# 24  68872      Marcelo Lomba  PAL       GK                     NaN
# 25  68899  Philippe Coutinho  VAS       MD                   10.80
# 26  68920               Dudu  CAM       AT                    2.50
# 27  68928             Rafael  SAO       GK                    4.20
# 28  68938   Giovanni Augusto  CHA       MD                    1.70
# 29  68952            Marinho  VIT       AT                     NaN
#
#     pts_std_played__last_3  pts_avg_played__last_5  pts_std_played__last_5  \
# 0                      NaN                    2.10                     NaN
# 1                      NaN                    5.30                     NaN
# 2                      NaN                   -0.10                     NaN
# 3                      NaN                    8.07                     NaN
# 4                      NaN                    6.60                     NaN
# 5                      NaN                   -0.30                     NaN
# 6                      NaN                    0.80                     NaN
# 7                      NaN                   -2.70                     NaN
# 8                      NaN                    0.90                     NaN
# 9                      NaN                    1.37                     NaN
# 10                     NaN                     NaN                     NaN
# 11                     NaN                    4.20                     NaN
# 12                     NaN                    1.50                     NaN
# 13                     NaN                    1.00                     NaN
# 14                     NaN                   -0.30                     NaN
# 15                     NaN                     NaN                     NaN
# 16                     NaN                     NaN                     NaN
# 17                     NaN                    0.00                     NaN
# 18                     NaN                    2.50                     NaN
# 19                     NaN                     NaN                     NaN
# 20                     NaN                    3.00                     NaN
# 21                     NaN                    7.00                     NaN
# 22                     NaN                   10.20                     NaN
# 23                     NaN                     NaN                     NaN
# 24                     NaN                     NaN                     NaN
# 25                     NaN                   10.80                     NaN
# 26                     NaN                    2.50                     NaN
# 27                     NaN                    4.20                     NaN
# 28                     NaN                    1.70                     NaN
# 29                     NaN                     NaN                     NaN
#
#     pts_avg_played__last_10  pts_std_played__last_10  matches_played_in_last_5
# 0                      2.10                      NaN                         1
# 1                      5.30                      NaN                         1
# 2                     -0.10                      NaN                         1
# 3                      8.07                      NaN                         1
# 4                      6.60                      NaN                         1
# 5                     -0.30                      NaN                         1
# 6                      0.80                      NaN                         1
# 7                     -2.70                      NaN                         1
# 8                      0.90                      NaN                         1
# 9                      1.37                      NaN                         1
# 10                      NaN                      NaN                         0
# 11                     4.20                      NaN                         1
# 12                     1.50                      NaN                         1
# 13                     1.00                      NaN                         1
# 14                    -0.30                      NaN                         1
# 15                      NaN                      NaN                         0
# 16                      NaN                      NaN                         0
# 17                     0.00                      NaN                         1
# 18                     2.50                      NaN                         1
# 19                      NaN                      NaN                         0
# 20                     3.00                      NaN                         1
# 21                     7.00                      NaN                         1
# 22                    10.20                      NaN                         1
# 23                      NaN                      NaN                         0
# 24                      NaN                      NaN                         0
# 25                    10.80                      NaN                         1
# 26                     2.50                      NaN                         1
# 27                     4.20                      NaN                         1
# 28                     1.70                      NaN                         1
# 29                      NaN                      NaN                         0

# %%
# Last 3 matches

# Calculate mean and std of top X players per position
topX_means = data_26.groupby("position")["pts_avg_played__last_3"].apply(lambda x: x.nlargest(dict_num_players[x.name]).mean())
topX_stds = data_26.groupby("position")["pts_avg_played__last_3"].apply(lambda x: x.nlargest(dict_num_players[x.name]).std())

data_26["position__pts_avg_played__last_3"] = data_26["position"].map(topX_means)
data_26["position__pts_std_played__last_3"] = data_26["position"].map(topX_stds)

# Calculate z-score
data_26["pts_avg_played__vs_top_position__last_3"] = data_26["pts_avg_played__last_3"] - data_26["position__pts_avg_played__last_3"]
data_26["pts_z_played__vs_top_position__last_3"] = (data_26["pts_avg_played__last_3"] - data_26["position__pts_avg_played__last_3"]) / data_26["position__pts_std_played__last_3"]



# Calculate mean and std of top 200 players
data_26["general__pts_avg_played__last_3"] = data_26["pts_avg_played__last_3"].nlargest(200).mean()
data_26["general__pts_std_played__last_3"] = data_26["pts_avg_played__last_3"].nlargest(200).std()

# Calculate z-score
data_26["pts_avg_played__vs_top_general__last_3"] = data_26["pts_avg_played__last_3"] - data_26["general__pts_avg_played__last_3"]
data_26["pts_z_played__vs_top_general__last_3"] = (data_26["pts_avg_played__last_3"] - data_26["general__pts_avg_played__last_3"]) / data_26["general__pts_std_played__last_3"]

# %%
# Last 5 matches

# Calculate mean and std of top X players per position
topX_means = data_26.groupby("position")["pts_avg_played__last_5"].apply(lambda x: x.nlargest(dict_num_players[x.name]).mean())
topX_stds = data_26.groupby("position")["pts_avg_played__last_5"].apply(lambda x: x.nlargest(dict_num_players[x.name]).std())

data_26["position__pts_avg_played__last_5"] = data_26["position"].map(topX_means)
data_26["position__pts_std_played__last_5"] = data_26["position"].map(topX_stds)

# Calculate z-score
data_26["pts_avg_played__vs_top_position__last_5"] = data_26["pts_avg_played__last_5"] - data_26["position__pts_avg_played__last_5"]
data_26["pts_z_played__vs_top_position__last_5"] = (data_26["pts_avg_played__last_5"] - data_26["position__pts_avg_played__last_5"]) / data_26["position__pts_std_played__last_5"]



# Calculate mean and std of top 200 players
data_26["general__pts_avg_played__last_5"] = data_26["pts_avg_played__last_5"].nlargest(200).mean()
data_26["general__pts_std_played__last_5"] = data_26["pts_avg_played__last_5"].nlargest(200).std()

# Calculate z-score
data_26["pts_avg_played__vs_top_general__last_5"] = data_26["pts_avg_played__last_5"] - data_26["general__pts_avg_played__last_5"]
data_26["pts_z_played__vs_top_general__last_5"] = (data_26["pts_avg_played__last_5"] - data_26["general__pts_avg_played__last_5"]) / data_26["general__pts_std_played__last_5"]

# %%
# Last 10 matches

# Calculate mean and std of top X players per position
topX_means = data_26.groupby("position")["pts_avg_played__last_10"].apply(lambda x: x.nlargest(dict_num_players[x.name]).mean())
topX_stds = data_26.groupby("position")["pts_avg_played__last_10"].apply(lambda x: x.nlargest(dict_num_players[x.name]).std())

data_26["position__pts_avg_played__last_10"] = data_26["position"].map(topX_means)
data_26["position__pts_std_played__last_10"] = data_26["position"].map(topX_stds)

# Calculate z-score
data_26["pts_avg_played__vs_top_position__last_10"] = data_26["pts_avg_played__last_10"] - data_26["position__pts_avg_played__last_10"]
data_26["pts_z_played__vs_top_position__last_10"] = (data_26["pts_avg_played__last_10"] - data_26["position__pts_avg_played__last_10"]) / data_26["position__pts_std_played__last_10"]



# Calculate mean and std of top 200 players
data_26["general__pts_avg_played__last_10"] = data_26["pts_avg_played__last_10"].nlargest(200).mean()
data_26["general__pts_std_played__last_10"] = data_26["pts_avg_played__last_10"].nlargest(200).std()

# Calculate z-score
data_26["pts_avg_played__vs_top_general__last_10"] = data_26["pts_avg_played__last_10"] - data_26["general__pts_avg_played__last_10"]
data_26["pts_z_played__vs_top_general__last_10"] = (data_26["pts_avg_played__last_10"] - data_26["general__pts_avg_played__last_10"]) / data_26["general__pts_std_played__last_10"]

# %%
# Last 3 matches

# Ranking players per position based on Z-scores
data_26["adp_position__last_3"] = data_26.groupby("position")["pts_z_played__vs_top_position__last_3"].rank(ascending=False, method="min").astype(int)
data_26.sort_values(by=["adp_position__last_3"], ascending=True).head(20)

# Ranking all players based on Z-scores
data_26["adp_general__last_3"] = data_26["dvs_general_adj"].rank(ascending=False, method="min").astype(int)
data_26.sort_values(by="dvs_general_adj", ascending=False).head(20)

# %%
# Média de pontos últimos 3 jogos (apenas jogados)
# Média de pontos últimos 5 jogos (apenas jogados)
# Média de pontos últimos 10 jogos (apenas jogados)

# Desvio padrão de pontos últimos 3 jogos (apenas jogados)
# Desvio padrão de pontos últimos 5 jogos (apenas jogados)
# Desvio padrão de pontos últimos 10 jogos (apenas jogados)

# Disponibilidade últimos 5 jogos

# DVS posição considerando apenas últimos 3 jogos
# DVS posição considerando apenas últimos 5 jogos
# DVS posição considerando apenas últimos 10 jogos

# DVS geral considerando apenas últimos 3 jogos
# DVS geral considerando apenas últimos 5 jogos
# DVS geral considerando apenas últimos 10 jogos

# ADP posição considerando apenas últimos 3 jogos
# ADP posição considerando apenas últimos 5 jogos
# ADP posição considerando apenas últimos 10 jogos

# ADP geral considerando apenas últimos 3 jogos
# ADP geral considerando apenas últimos 5 jogos
# ADP geral considerando apenas últimos 10 jogos
